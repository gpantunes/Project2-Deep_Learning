# %% [markdown]
# # Imports

# %%
from snake_game import SnakeGame
import matplotlib.pyplot as plt
import numpy as np
from numpy.random import randint
#import imageio # For video generation

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from collections import deque
import random
import time
import matplotlib.pyplot as plt

# %% [markdown]
# # Heuristic Player

# %%
"""
    Heuristic Player
"""
class SnakeHeuristic:
    def __init__(self, game: SnakeGame):
        self.game = game
        # Map: game_direction_idx -> (row_change, col_change)
        self.delta_coords = {
            0: (-1, 0),  # Up
            1: (0, 1),   # Right
            2: (1, 0),   # Down
            3: (0, -1)   # Left
        }

    def _get_closest_apple_pos(self):
        if not self.game.apples:
            return None

        head_r, head_c = self.game.snake[0]
        closest_apple = None
        min_dist = float('inf')

        for apple_r, apple_c in self.game.apples:
            dist = abs(apple_r - head_r) + abs(apple_c - head_c)
            if dist < min_dist:
                min_dist = dist
                closest_apple = (apple_r, apple_c)
        return closest_apple

    def _is_safe_move(self, next_head_r, next_head_c):
        if not (0 <= next_head_r < self.game.height and \
                0 <= next_head_c < self.game.width):
            return False

        if (next_head_r, next_head_c) in self.game.snake[1:]:
            return False

        return True

    def choose_action(self):
        target_apple_pos = self._get_closest_apple_pos()

        if target_apple_pos is None:
            return 0

        head_r, head_c = self.game.snake[0]
        current_game_direction = self.game.direction

        candidate_actions = []

        for action_value in [-1, 0, 1]:
            next_game_direction = (current_game_direction + action_value) % 4
            if next_game_direction < 0: next_game_direction += 4

            dr, dc = self.delta_coords[next_game_direction]

            next_head_r, next_head_c = head_r + dr, head_c + dc

            if self._is_safe_move(next_head_r, next_head_c):
                dist_to_apple = abs(target_apple_pos[0] - next_head_r) + \
                                abs(target_apple_pos[1] - next_head_c)
                candidate_actions.append({
                    'action': action_value,
                    'distance': dist_to_apple
                })

        if not candidate_actions:
            return 0

        def sort_key(candidate):
            action = candidate['action']
            preference = 0
            if action == 1: preference = 1
            elif action == -1: preference = 2
            return (candidate['distance'], preference)

        candidate_actions.sort(key=sort_key)

        return candidate_actions[0]['action']

    def play_game_and_record(self, max_steps: int, video_filename: str = "snake_heuristic_game.gif", fps: int = 5):
        frames = []
        history = {
            'board': [],
            'reward': [],
            'done': -1,
            'info': []
        }
        board_state, reward, done, info = self.game.reset()

        frames.append((board_state * 255).astype(np.uint8))

        print(f"Starting game with heuristic. Max steps: {max_steps}. Recording to {video_filename}")

        for step_num in range(max_steps):
            history['board'].append(board_state)
            history['reward'].append(reward)
            history['info'].append(info)
            if done:
                history['done'] = step_num
                print(f"Game ended prematurely at step {step_num} before taking action. Score: {info['score']}")
                break

            action_to_take = self.choose_action()
            board_state, reward, done, info = self.game.step(action_to_take)

            frames.append((board_state * 255).astype(np.uint8))

            if (step_num + 1) % 100 == 0:
                 print(f"Step {step_num+1}/{max_steps}, Score: {info['score']}, Done: {done}")


            """if done:
                print(f"Game over at step {step_num+1}. Final Score: {info['score']}")
                break"""
        else:
            print(f"Game finished after {max_steps} steps (max_steps reached). Final Score: {self.game.score}")

        if frames:
            print(f"Saving video with {len(frames)} frames at {fps} FPS...")
            try:
                imageio.mimsave(video_filename, frames, fps=fps)
                print(f"Video saved successfully as {video_filename}")
            except Exception as e:
                print(f"Error saving video: {e}")
                print("Please ensure you have an imageio backend installed (e.g., 'pip install imageio[ffmpeg]' for MP4 or 'pip install imageio pillow' for GIF).")
        else:
            print("No frames recorded.")

        return history

# %%
"""
    Simple heuristic for training
    Does not avoid collisions with walls and itself
    Did not seem to be a problem
    If it happens, its a learning experience
"""
def get_ideal_direction(food_coords, head_coords, direction):
    dx = food_coords[0] - head_coords[0]  # positive = food is to the right
    dy = food_coords[1] - head_coords[1]  # positive = food is above
    W, N, E, S = 0, 1, 2, 3    # this may look wrong but I have to do this so this works, I didnt bother finding out why sorry :P
    LEFT, SAME_DIR, RIGHT = -1, 0, 1
    GO = 0 # default is going in the same direction

    if dx == 0:         # food on same x axis
        if dy > 0:      # food above
            if direction == N:   # going up
                GO = SAME_DIR        # keep going up
            elif direction == E:   # going right
                GO = LEFT
            else:
                GO = RIGHT  # if going left or up
        else:
            if direction == S:   # going up
                GO = SAME_DIR        # keep going up
            elif direction == E:   # going right
                GO = RIGHT
            else:
                GO = LEFT      # if going left or up

    elif dx > 0:
        if direction == N or direction == W: # if going up or in the opposite direction turn right
            GO = RIGHT
        elif direction == S:
            GO = LEFT
        elif direction == E:
            GO = SAME_DIR
    else:
        if direction == S or direction == E: # if going down or in the opposite direction turn right
            GO = RIGHT
        elif direction == N:
            GO = LEFT
        elif direction == W:
            GO = SAME_DIR

    return GO

# %%
def heuristic_move(game):
    total_score, food_coords, head_coords, tails_coords, direction = game.get_state()
    next_move = get_ideal_direction(food_coords[0], head_coords, direction)
    return next_move

# %%
# do episode_demo(game_instance) to try
def episode_demo(game):
    frames = []
    state, reward, done, info = game.reset()
    frames.append((state * 255).astype(np.uint8))
    #direction_array = [3, 0, 1, 2]
    step = 0
    while not done and step < 500:
        total_score, food_coords, head_coords, tails_coords, direction = game.get_state()
        next_move = get_ideal_direction(food_coords[0], head_coords, direction)
        state, reward, done, info = game_instance.step(next_move)
        frames.append((state * 255).astype(np.uint8))

    imageio.mimsave("demo.gif", frames, fps=5)

# %% [markdown]
# # SnakeDQN Definition

# %%
def evaluate_dqn_policy(game: SnakeGame, policy_net: nn.Module, max_steps: int, video_filename=None, fps=5):
    frames = []
    state, _, done, info = game.reset()
    state = np.transpose(state, (2, 0, 1))  # CHW for PyTorch

    if video_filename:
        frames.append((np.transpose(state, (1, 2, 0)) * 255).astype(np.uint8))

    total_reward = 0
    for step in range(max_steps):
        if done:
            break

        with torch.no_grad():
            state_tensor = torch.tensor(state, dtype=torch.float32).unsqueeze(0)
            q_values = policy_net(state_tensor)
            action_idx = q_values.argmax().item()
            action = [-1, 0, 1][action_idx]

        next_state, reward, done, info = game.step(action)
        next_state = np.transpose(next_state, (2, 0, 1))
        state = next_state
        total_reward += reward

        if video_filename:
            frame = (np.transpose(state, (1, 2, 0)) * 255).astype(np.uint8)
            frames.append(frame)

    #if video_filename and frames:
        #imageio.mimsave(video_filename, frames, fps=fps)

    return info['score'], total_reward


"""
    DQN, Replay Buffer, and Helper Functions
"""
class SnakeDQN(nn.Module):
    def __init__(self, input_shape, n_actions):
        super(SnakeDQN, self).__init__()
        C, H, W = input_shape

        self.conv = nn.Sequential(
            nn.Conv2d(C, 32, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),
            nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),
        )

        dummy_input = torch.zeros(1, *input_shape)
        conv_out_size = self.conv(dummy_input).view(1, -1).shape[1]

        self.fc = nn.Sequential(
            nn.Linear(conv_out_size, 128),
            nn.ReLU(),
            nn.Linear(128, n_actions)
        )

    def forward(self, x):
        x = self.conv(x)
        x = x.view(x.size(0), -1)
        return self.fc(x)

def compute_q_loss(pred_q, action, reward, next_state, done, model, gamma=0.99):
    with torch.no_grad():
        next_q = model(next_state)
        max_next_q = next_q.max(1)[0]
        target_q = reward + gamma * max_next_q * (1 - done)

    pred_q_action = pred_q.gather(1, action.unsqueeze(1)).squeeze(1)
    loss = F.mse_loss(pred_q_action, target_q)
    return loss

def compute_loss(predicted_q_values, actions, target_q_values):
    action_indices = actions + 1
    selected_q = predicted_q_values.gather(1, action_indices.unsqueeze(1)).squeeze(1)
    loss = F.mse_loss(selected_q, target_q_values)
    return loss, selected_q

def boltzmann_action(q_values, temperature):
    probabilities = F.softmax(q_values / temperature, dim=1)
    return torch.multinomial(probabilities, 1).item()

class ReplayBuffer:
    def __init__(self, capacity=10000):
        self.buffer = deque(maxlen=capacity)

    def push(self, state, action, reward, next_state, done):
        self.buffer.append((state, action, reward, next_state, done))

    def sample(self, batch_size):
        samples = random.sample(self.buffer, min(batch_size, len(self.buffer)))
        states, actions, rewards, next_states, dones = zip(*samples)

        return (
            torch.tensor(np.array(states), dtype=torch.float32),
            torch.tensor(actions, dtype=torch.int64),
            torch.tensor(rewards, dtype=torch.float32),
            torch.tensor(np.array(next_states), dtype=torch.float32),
            torch.tensor(dones, dtype=torch.bool)
        )

    def __len__(self):
        return len(self.buffer)

# %% [markdown]
# # Task 1 Train

# %%
def plot_training_metrics(scores, losses, q_values):
    import matplotlib.pyplot as plt

    plt.figure(figsize=(18, 5))

    plt.subplot(1, 3, 1)
    plt.plot(scores)
    plt.title("Scores")
    plt.xlabel("Episode")
    plt.ylabel("Score")

    plt.subplot(1, 3, 2)
    plt.plot(losses)
    plt.title("Average Loss per Episode")
    plt.xlabel("Episode")
    plt.ylabel("Loss")

    plt.subplot(1, 3, 3)
    plt.plot(q_values)
    plt.title("Average Q-value per Episode")
    plt.xlabel("Episode")
    plt.ylabel("Q-value")

    plt.tight_layout()
    plt.show()


def evaluate_efficiency(scores, q_values, total_time):
    avg_score = np.mean(scores)
    avg_q = np.mean(q_values)
    print(f"--- Evaluation Summary ---")
    print(f"Average Score: {avg_score:.2f}")
    print(f"Average Q-value: {avg_q:.4f}")
    print(f"Training Time: {total_time:.2f} seconds")
    print(f"Score / Time: {avg_score / total_time:.4f}")
    print(f"Q-value / Time: {avg_q / total_time:.4f}")


"""
    Task 1 - train simple
"""
def train_dqn_simple(env, model, max_train_episodes = 1000, using_heuristic = False):
    optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)

    scores = []
    losses = []
    q_values = []

    epsilon = EPSILON_START

    for episode in range(1, max_train_episodes + 1):
        state, _, done, _ = env.reset()
        state = np.transpose(state, (2, 0, 1))
        state = torch.tensor(state, dtype=torch.float32).unsqueeze(0).to(device)

        total_loss = 0
        total_q = 0
        steps = 0
        done = False

        while not done and steps < MAX_GAME_STEPS:
            if using_heuristic and random.random() < epsilon:
                action = heuristic_move(env)
            else:
                with torch.no_grad():
                    q_vals = model(state)
                    action_idx = q_vals.argmax().item()
                    action = [-1, 0, 1][action_idx]

            next_state, reward, done, info = env.step(action)

            next_state = np.transpose(next_state, (2, 0, 1))
            next_state_tensor = torch.tensor(next_state, dtype=torch.float32).unsqueeze(0).to(device)

            reward_tensor = torch.tensor([reward], dtype=torch.float32).to(device)
            done_tensor = torch.tensor([done], dtype=torch.float32).to(device)
            action_tensor = torch.tensor([[-1, 0, 1].index(action)], dtype=torch.int64).to(device)

            pred_q = model(state)
            loss = compute_q_loss(pred_q, action_tensor, reward_tensor, next_state_tensor, done_tensor, model)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            with torch.no_grad():
                action_index = torch.tensor([[[-1, 0, 1].index(action)]], dtype=torch.int64).to(device)
                action_index = action_index.view(1, 1)
                q_val_taken = pred_q.gather(1, action_index).mean().item()
                total_q += q_val_taken

            total_loss += loss.detach()
            state = next_state_tensor
            steps += 1


        scores.append(info['score'])
        losses.append(float(total_loss.cpu()) / steps if steps > 0 else 0)
        q_values.append(total_q / steps if steps > 0 else 0)

        if episode % 10 == 0:
            epsilon = max(EPSILON_END, epsilon*EPSILON_DECAY)
            print(f"Episode {episode} | Score: {info['score']:.2f} | Loss: {losses[-1]:.4f} | Q-value: {q_values[-1]:.4f} Epsilon: {epsilon:.4f}")

        if episode % 50 == 0:
            avg_score = sum(scores[-50:]) / 50
            print(f"Episode {episode}, Avg Score: {avg_score:.2f}")

    return model, scores, losses, q_values

# %% [markdown]
# # Task 2 onward?

# %%
def start_buffer_with_heuristic(replay_buffer, game_class, num_games=50):
    print(f"\n[Warm Start] Filling buffer with {num_games} heuristic games...")
    total_score = 0
    for i in range(num_games):
        game = SnakeGame(GAME_WIDTH, GAME_HEIGHT, FOOD_AMOUNT, BORDER_SIZE, GRASS_GROWTH, MAX_GRASS)
        board_state, _, done, _ = game.reset()
        heuristic = SnakeHeuristic(game)
        state = np.transpose(board_state, (2, 0, 1))
        game_score = 0

        while not done:
            action = heuristic.choose_action()
            next_board_state, reward, done, _ = game.step(action)
            next_state = np.transpose(next_board_state, (2, 0, 1))

            replay_buffer.push(state, action, reward, next_state, done)
            state = next_state
            game_score += reward

        total_score += game_score

    avg_score = total_score / num_games
    print(f"[Heuristic Baseline] Average score over {num_games} games: {avg_score:.2f}")
    #return avg_score
    return game

"""
    Must define exploration style "epsilon" or "boltzmann"
    If using epsilon, must define decay_pattern as "linear", "exponential" or "step"
"""
def train_dqn3(game, policy_net, target_net, exploration_style="epsilon", temperature = TEMPERATURE_START, decay_pattern = "linear", max_train_episodes=500):
    optimizer = optim.Adam(policy_net.parameters(), lr=LEARNING_RATE)
    replay_buffer = ReplayBuffer(REPLAY_BUFFER_SIZE)

    # === Heuristic warm-up ===
    game = start_buffer_with_heuristic(replay_buffer, game, num_games=50)

    epsilon = 0.05 if decay_pattern == "fixed" else EPSILON_START

    epsilon = EPSILON_START
    total_steps = 0
    max_total_steps = max_train_episodes*MAX_GAME_STEPS
    epsilon_decay_rate = -np.log(EPSILON_END / EPSILON_START) / max_total_steps
    step_size = max_total_steps * 0.75 * 0.01
    decay_per_step = (EPSILON_START - EPSILON_END) * 0.01
    temperature_decay_rate = -np.log(TEMPERATURE_END / TEMPERATURE_START) / max_total_steps

    scores, losses, q_values = [], [], []

    for episode in range(1, max_train_episodes + 1):
        state, _, done, _ = game.reset()
        state = np.transpose(state, (2, 0, 1))

        total_loss, total_q, steps = 0, 0, 0
        for _ in range(MAX_GAME_STEPS):
            total_steps += 1
            steps += 1

            if exploration_style == "epsilon" and random.random() < epsilon:
                action = [-1, 0, 1][random.randint(0, 2)]
            else:
                with torch.no_grad():
                    state_tensor = torch.tensor(state, dtype=torch.float32).unsqueeze(0)
                    q_vals = policy_net(state_tensor)
                    action_idx = -99
                    if exploration_style == "boltzmann":
                        action_idx = boltzmann_action(q_vals, temperature)
                    else:
                        action_idx = q_vals.argmax().item()
                    action = [-1, 0, 1][action_idx]

            next_state, reward, done, info = game.step(action)
            next_state = np.transpose(next_state, (2, 0, 1))
            replay_buffer.push(state, action, reward, next_state, done)
            state = next_state

            if len(replay_buffer) >= BATCH_SIZE:
                states, actions, rewards, next_states, dones = replay_buffer.sample(BATCH_SIZE)

                with torch.no_grad():
                    next_q = target_net(next_states).max(1)[0]
                    target_q = rewards + (1 - dones.float()) * GAMMA * next_q

                predicted_q = policy_net(states)
                loss, q_val_taken = compute_loss(predicted_q, actions, target_q)

                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

                total_loss += loss.detach()
                total_q += float(q_val_taken.detach().mean())

            # Update target network
            if total_steps % TARGET_UPDATE_FREQ == 0:
                target_net.load_state_dict(policy_net.state_dict())

            if done:
                break

        if exploration_style == "boltzmann":
            temperature = max(TEMPERATURE_END, TEMPERATURE_START * np.exp(-temperature_decay_rate * total_steps))
        elif exploration_style == "epsilon":
            if decay_pattern == "linear":
                #epsilon = max(EPSILON_END, epsilon * EPSILON_DECAY)
                epsilon = max(EPSILON_END, epsilon - (EPSILON_START - EPSILON_END) / max_total_steps)
            elif decay_pattern == "exponential":
                epsilon = max(EPSILON_END, epsilon * np.exp(-epsilon_decay_rate * total_steps))
            elif decay_pattern == "step":
                if total_steps % step_size == 0:
                    epsilon = max(EPSILON_END, epsilon - decay_per_step)
        else:
            print("Wrong decay pattern")

        scores.append(info['score'])
        losses.append(float(total_loss.cpu()) / steps if steps > 0 else 0)
        q_values.append(total_q / steps if steps > 0 else 0)

        if episode % 10 == 0:
            print(f"Episode {episode} | Score: {info['score']:.2f} | Loss: {losses[-1]:.4f} | Q-value: {q_values[-1]:.4f} | Eps: {epsilon:.3f}" if exploration_style == "epsilon"
                  else f"Episode {episode} | Score: {info['score']:.2f} | Loss: {losses[-1]:.4f} | Q-value: {q_values[-1]:.4f} | Temp: {temperature:.3f}")

        if episode % 50 == 0:
            avg_score = sum(scores[-50:]) / 50
            print(f"Episode {episode}, Avg Score: {avg_score:.2f}")

    return scores, losses, q_values

# %% [markdown]
# # Training

# %%
GAME_WIDTH = 30
GAME_HEIGHT = 30
FOOD_AMOUNT = 1
GRASS_GROWTH = 0
MAX_GRASS = 0
BORDER_SIZE = 1 # Add a visual border of 1 pixel
MAX_GAME_STEPS = 500 # Set a limit for the game length
FPS = 5 # Faster for smoother video

BATCH_SIZE = 64
GAMMA = 0.99
EPSILON_START = 1
EPSILON_END = 0.005
EPSILON_DECAY = 0.995
REPLAY_BUFFER_SIZE = 1000
LEARNING_RATE = 1e-4
TARGET_UPDATE_FREQ = 100
EVAL_INTERVAL = 500
TEMPERATURE_END = 0.1
TEMPERATURE_START = 2.0

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
game_instance = SnakeGame(
    width=GAME_WIDTH,
    height=GAME_HEIGHT,
    food_amount=FOOD_AMOUNT,
    border=BORDER_SIZE,
    grass_growth=GRASS_GROWTH,
    max_grass=MAX_GRASS)

# %%
state = game_instance.reset()[0]
state = np.transpose(state, (2, 0, 1))
state_shape = state.shape

# %%
## TASK 1
model = SnakeDQN(state_shape, n_actions=3).to(device)

start = time.time()
trained_model, scores, losses, q_values = train_dqn_simple(game_instance, model, max_train_episodes=5000, using_heuristic=True)
end = time.time()
# Out:
# Episode 10 | Score: 14.00 | Loss: 0.8804 | Q-value: 13.3781 Epsilon: 0.9950
# Episode 20 | Score: 4.00 | Loss: 0.8485 | Q-value: 7.9842 Epsilon: 0.9900
# Episode 30 | Score: 0.00 | Loss: 2.9209 | Q-value: 7.5190 Epsilon: 0.9851
# Episode 40 | Score: 17.00 | Loss: 0.2906 | Q-value: 7.7541 Epsilon: 0.9801
# Episode 50 | Score: 13.00 | Loss: 0.4803 | Q-value: 9.2083 Epsilon: 0.9752
# Episode 50, Avg Score: 11.72
# Episode 60 | Score: 17.00 | Loss: 0.2814 | Q-value: 7.0166 Epsilon: 0.9704
# Episode 70 | Score: 12.00 | Loss: 0.2149 | Q-value: 5.3805 Epsilon: 0.9655
# Episode 80 | Score: 14.00 | Loss: 0.2231 | Q-value: 5.3149 Epsilon: 0.9607
# Episode 90 | Score: 6.00 | Loss: 0.5235 | Q-value: 5.7701 Epsilon: 0.9559
# Episode 100 | Score: 4.00 | Loss: 0.8889 | Q-value: 6.5956 Epsilon: 0.9511
# Episode 100, Avg Score: 10.78
# Episode 110 | Score: 5.00 | Loss: 0.4591 | Q-value: 5.9992 Epsilon: 0.9464
# Episode 120 | Score: 4.00 | Loss: 0.7873 | Q-value: 5.0064 Epsilon: 0.9416
# Episode 130 | Score: 13.00 | Loss: 0.3287 | Q-value: 6.5217 Epsilon: 0.9369
# Episode 140 | Score: 2.00 | Loss: 0.6089 | Q-value: 5.3080 Epsilon: 0.9322
# Episode 150 | Score: 2.00 | Loss: 0.6725 | Q-value: 4.7459 Epsilon: 0.9276
# Episode 150, Avg Score: 8.56
# Episode 160 | Score: 2.00 | Loss: 0.9672 | Q-value: 4.3154 Epsilon: 0.9229
# Episode 170 | Score: 9.00 | Loss: 0.1988 | Q-value: 4.2841 Epsilon: 0.9183
# Episode 180 | Score: 5.00 | Loss: 0.2900 | Q-value: 6.4636 Epsilon: 0.9137
# Episode 190 | Score: 0.00 | Loss: 3.9208 | Q-value: 4.4063 Epsilon: 0.9092
# Episode 200 | Score: 3.00 | Loss: 1.0485 | Q-value: 7.8810 Epsilon: 0.9046
# Episode 200, Avg Score: 7.92
# Episode 210 | Score: 3.00 | Loss: 0.6893 | Q-value: 6.6325 Epsilon: 0.9001
# Episode 220 | Score: 7.00 | Loss: 0.2207 | Q-value: 4.4341 Epsilon: 0.8956
# Episode 230 | Score: 2.00 | Loss: 1.2809 | Q-value: 7.5821 Epsilon: 0.8911
# Episode 240 | Score: 9.00 | Loss: 0.3933 | Q-value: 6.2416 Epsilon: 0.8867
# Episode 250 | Score: 1.00 | Loss: 1.3923 | Q-value: 6.1514 Epsilon: 0.8822
# Episode 250, Avg Score: 6.86
# Episode 260 | Score: 5.00 | Loss: 0.6297 | Q-value: 6.0009 Epsilon: 0.8778
# Episode 270 | Score: 7.00 | Loss: 0.6946 | Q-value: 10.0712 Epsilon: 0.8734
# Episode 280 | Score: 2.00 | Loss: 0.7402 | Q-value: 5.2727 Epsilon: 0.8691
# Episode 290 | Score: 19.00 | Loss: 0.2876 | Q-value: 6.6092 Epsilon: 0.8647
# Episode 300 | Score: 8.00 | Loss: 0.6551 | Q-value: 6.2698 Epsilon: 0.8604
# Episode 300, Avg Score: 6.88
# Episode 310 | Score: 7.00 | Loss: 0.1822 | Q-value: 5.0626 Epsilon: 0.8561
# Episode 320 | Score: 23.00 | Loss: 0.0405 | Q-value: 4.7189 Epsilon: 0.8518
# Episode 330 | Score: 7.00 | Loss: 0.6722 | Q-value: 6.7771 Epsilon: 0.8475
# Episode 340 | Score: 15.00 | Loss: 0.2512 | Q-value: 6.4119 Epsilon: 0.8433
# Episode 350 | Score: 1.00 | Loss: 2.0941 | Q-value: 6.7133 Epsilon: 0.8391
# Episode 350, Avg Score: 6.34
# Episode 360 | Score: 1.00 | Loss: 1.3073 | Q-value: 5.5843 Epsilon: 0.8349
# Episode 370 | Score: 3.00 | Loss: 2.4529 | Q-value: 6.3033 Epsilon: 0.8307
# Episode 380 | Score: 6.00 | Loss: 0.2136 | Q-value: 5.2498 Epsilon: 0.8266
# Episode 390 | Score: 5.00 | Loss: 0.3180 | Q-value: 3.9909 Epsilon: 0.8224
# Episode 400 | Score: 8.00 | Loss: 0.5563 | Q-value: 7.4094 Epsilon: 0.8183
# Episode 400, Avg Score: 5.54
# Episode 410 | Score: 9.00 | Loss: 0.3534 | Q-value: 7.7765 Epsilon: 0.8142
# Episode 420 | Score: 11.00 | Loss: 0.8503 | Q-value: 9.2702 Epsilon: 0.8102
# Episode 430 | Score: 1.00 | Loss: 1.8984 | Q-value: 8.1397 Epsilon: 0.8061
# Episode 440 | Score: 12.00 | Loss: 0.3674 | Q-value: 6.7527 Epsilon: 0.8021
# Episode 450 | Score: 5.00 | Loss: 0.4052 | Q-value: 6.1317 Epsilon: 0.7981
# Episode 450, Avg Score: 5.70
# Episode 460 | Score: 5.00 | Loss: 1.3488 | Q-value: 8.1697 Epsilon: 0.7941
# Episode 470 | Score: 8.00 | Loss: 0.1921 | Q-value: 5.8514 Epsilon: 0.7901
# Episode 480 | Score: 1.00 | Loss: 1.0719 | Q-value: 6.3304 Epsilon: 0.7862
# Episode 490 | Score: 7.00 | Loss: 0.2211 | Q-value: 5.6623 Epsilon: 0.7822
# Episode 500 | Score: 4.00 | Loss: 1.2176 | Q-value: 5.6996 Epsilon: 0.7783
# Episode 500, Avg Score: 4.60
# Episode 510 | Score: 9.00 | Loss: 0.2319 | Q-value: 5.4662 Epsilon: 0.7744
# Episode 520 | Score: 14.00 | Loss: 0.2539 | Q-value: 5.6138 Epsilon: 0.7705
# Episode 530 | Score: 0.00 | Loss: 15.5772 | Q-value: 6.1963 Epsilon: 0.7667
# Episode 540 | Score: 3.00 | Loss: 1.0970 | Q-value: 6.4976 Epsilon: 0.7629
# Episode 550 | Score: 3.00 | Loss: 2.8433 | Q-value: 7.3792 Epsilon: 0.7590
# Episode 550, Avg Score: 4.56
# Episode 560 | Score: 5.00 | Loss: 0.5168 | Q-value: 7.1919 Epsilon: 0.7553
# Episode 570 | Score: 5.00 | Loss: 0.4333 | Q-value: 5.6139 Epsilon: 0.7515
# Episode 580 | Score: 1.00 | Loss: 1.3620 | Q-value: 5.7100 Epsilon: 0.7477
# Episode 590 | Score: 4.00 | Loss: 0.6325 | Q-value: 6.9596 Epsilon: 0.7440
# Episode 600 | Score: 6.00 | Loss: 0.9890 | Q-value: 10.1816 Epsilon: 0.7403
# Episode 600, Avg Score: 4.26
# Episode 610 | Score: 6.00 | Loss: 1.1144 | Q-value: 9.8558 Epsilon: 0.7366
# Episode 620 | Score: 1.00 | Loss: 1.1502 | Q-value: 7.2922 Epsilon: 0.7329
# Episode 630 | Score: 4.00 | Loss: 0.5851 | Q-value: 6.6012 Epsilon: 0.7292
# Episode 640 | Score: 0.00 | Loss: 6.2922 | Q-value: 8.0239 Epsilon: 0.7256
# Episode 650 | Score: 8.00 | Loss: 0.4349 | Q-value: 6.9751 Epsilon: 0.7219
# Episode 650, Avg Score: 4.60
# Episode 660 | Score: 6.00 | Loss: 0.3442 | Q-value: 5.5153 Epsilon: 0.7183
# Episode 670 | Score: 1.00 | Loss: 0.9229 | Q-value: 5.4992 Epsilon: 0.7147
# Episode 680 | Score: 1.00 | Loss: 0.3976 | Q-value: 4.0770 Epsilon: 0.7112
# Episode 690 | Score: 4.00 | Loss: 0.4219 | Q-value: 5.8589 Epsilon: 0.7076
# Episode 700 | Score: 0.00 | Loss: 6.3662 | Q-value: 8.3012 Epsilon: 0.7041
# Episode 700, Avg Score: 4.06
# Episode 710 | Score: 2.00 | Loss: 0.4728 | Q-value: 5.3652 Epsilon: 0.7005
# Episode 720 | Score: 4.00 | Loss: 0.6814 | Q-value: 6.3582 Epsilon: 0.6970
# Episode 730 | Score: 1.00 | Loss: 0.2702 | Q-value: 3.4476 Epsilon: 0.6936
# Episode 740 | Score: 6.00 | Loss: 0.2324 | Q-value: 5.5931 Epsilon: 0.6901
# Episode 750 | Score: 4.00 | Loss: 0.2902 | Q-value: 4.7281 Epsilon: 0.6866
# Episode 750, Avg Score: 3.90
# Episode 760 | Score: 2.00 | Loss: 0.5821 | Q-value: 5.2535 Epsilon: 0.6832
# Episode 770 | Score: 1.00 | Loss: 6.3006 | Q-value: 9.5034 Epsilon: 0.6798
# Episode 780 | Score: 4.00 | Loss: 0.3447 | Q-value: 5.3518 Epsilon: 0.6764
# Episode 790 | Score: 1.00 | Loss: 0.8037 | Q-value: 6.4787 Epsilon: 0.6730
# Episode 800 | Score: 7.00 | Loss: 0.2853 | Q-value: 5.5866 Epsilon: 0.6696
# Episode 800, Avg Score: 3.84
# Episode 810 | Score: 4.00 | Loss: 0.4084 | Q-value: 4.3572 Epsilon: 0.6663
# Episode 820 | Score: 7.00 | Loss: 0.3630 | Q-value: 7.5287 Epsilon: 0.6630
# Episode 830 | Score: 4.00 | Loss: 0.2705 | Q-value: 4.7337 Epsilon: 0.6597
# Episode 840 | Score: 6.00 | Loss: 0.4161 | Q-value: 5.1011 Epsilon: 0.6564
# Episode 850 | Score: 2.00 | Loss: 0.3168 | Q-value: 5.4398 Epsilon: 0.6531
# Episode 850, Avg Score: 3.98
# Episode 860 | Score: 4.00 | Loss: 0.4106 | Q-value: 6.9621 Epsilon: 0.6498
# Episode 870 | Score: 1.00 | Loss: 0.8582 | Q-value: 5.6482 Epsilon: 0.6466
# Episode 880 | Score: 3.00 | Loss: 0.6623 | Q-value: 4.7752 Epsilon: 0.6433
# Episode 890 | Score: 4.00 | Loss: 0.4933 | Q-value: 7.2346 Epsilon: 0.6401
# Episode 900 | Score: 1.00 | Loss: 1.5252 | Q-value: 5.6773 Epsilon: 0.6369
# Episode 900, Avg Score: 3.98
# Episode 910 | Score: 2.00 | Loss: 0.4819 | Q-value: 4.7076 Epsilon: 0.6337
# Episode 920 | Score: 2.00 | Loss: 0.9401 | Q-value: 4.9974 Epsilon: 0.6306
# Episode 930 | Score: 4.00 | Loss: 0.4597 | Q-value: 5.7578 Epsilon: 0.6274
# Episode 940 | Score: 12.00 | Loss: 0.2349 | Q-value: 6.2580 Epsilon: 0.6243
# Episode 950 | Score: 3.00 | Loss: 0.5955 | Q-value: 4.8179 Epsilon: 0.6211
# Episode 950, Avg Score: 3.42
# Episode 960 | Score: 1.00 | Loss: 2.0290 | Q-value: 6.5771 Epsilon: 0.6180
# Episode 970 | Score: 0.00 | Loss: 0.5790 | Q-value: 2.8858 Epsilon: 0.6149
# Episode 980 | Score: 9.00 | Loss: 0.2733 | Q-value: 5.6308 Epsilon: 0.6119
# Episode 990 | Score: 4.00 | Loss: 0.1531 | Q-value: 3.1510 Epsilon: 0.6088
# Episode 1000 | Score: 0.00 | Loss: 6.2858 | Q-value: 4.0766 Epsilon: 0.6058
# Episode 1000, Avg Score: 3.08
# Episode 1010 | Score: 2.00 | Loss: 0.1909 | Q-value: 3.3745 Epsilon: 0.6027
# Episode 1020 | Score: 0.00 | Loss: 1.3418 | Q-value: 4.4622 Epsilon: 0.5997
# Episode 1030 | Score: 0.00 | Loss: 1.7979 | Q-value: 5.2777 Epsilon: 0.5967
# Episode 1040 | Score: 8.00 | Loss: 0.5764 | Q-value: 6.1630 Epsilon: 0.5937
# Episode 1050 | Score: 1.00 | Loss: 0.4810 | Q-value: 5.2036 Epsilon: 0.5908
# Episode 1050, Avg Score: 3.40
# Episode 1060 | Score: 1.00 | Loss: 0.1760 | Q-value: 2.3822 Epsilon: 0.5878
# Episode 1070 | Score: 5.00 | Loss: 0.1619 | Q-value: 4.2793 Epsilon: 0.5849
# Episode 1080 | Score: 6.00 | Loss: 0.2615 | Q-value: 3.9527 Epsilon: 0.5820
# Episode 1090 | Score: 9.00 | Loss: 0.2049 | Q-value: 4.3007 Epsilon: 0.5790
# Episode 1100 | Score: 0.00 | Loss: 0.3993 | Q-value: 3.9610 Epsilon: 0.5762
# Episode 1100, Avg Score: 2.66
# Episode 1110 | Score: 1.00 | Loss: 0.0776 | Q-value: 1.4983 Epsilon: 0.5733
# Episode 1120 | Score: 1.00 | Loss: 0.2083 | Q-value: 2.4856 Epsilon: 0.5704
# Episode 1130 | Score: 0.00 | Loss: 0.1902 | Q-value: 1.5090 Epsilon: 0.5676
# Episode 1140 | Score: 3.00 | Loss: 0.3223 | Q-value: 4.3515 Epsilon: 0.5647
# Episode 1150 | Score: 4.00 | Loss: 0.2737 | Q-value: 3.7809 Epsilon: 0.5619
# Episode 1150, Avg Score: 2.48
# Episode 1160 | Score: 5.00 | Loss: 0.1695 | Q-value: 3.4429 Epsilon: 0.5591
# Episode 1170 | Score: 1.00 | Loss: 0.2261 | Q-value: 2.6941 Epsilon: 0.5563
# Episode 1180 | Score: 1.00 | Loss: 0.1246 | Q-value: 3.2100 Epsilon: 0.5535
# Episode 1190 | Score: 0.00 | Loss: 2.4253 | Q-value: 3.9983 Epsilon: 0.5507
# Episode 1200 | Score: 11.00 | Loss: 0.0910 | Q-value: 3.4948 Epsilon: 0.5480
# Episode 1200, Avg Score: 3.04
# Episode 1210 | Score: 12.00 | Loss: 0.2162 | Q-value: 4.3371 Epsilon: 0.5452
# Episode 1220 | Score: 1.00 | Loss: 0.2361 | Q-value: 3.8339 Epsilon: 0.5425
# Episode 1230 | Score: 2.00 | Loss: 0.4835 | Q-value: 3.2730 Epsilon: 0.5398
# Episode 1240 | Score: 2.00 | Loss: 0.2348 | Q-value: 3.8923 Epsilon: 0.5371
# Episode 1250 | Score: 2.00 | Loss: 0.1363 | Q-value: 1.8723 Epsilon: 0.5344
# Episode 1250, Avg Score: 2.68
# Episode 1260 | Score: 4.00 | Loss: 0.1570 | Q-value: 4.0690 Epsilon: 0.5318
# Episode 1270 | Score: 2.00 | Loss: 0.2122 | Q-value: 2.8261 Epsilon: 0.5291
# Episode 1280 | Score: 0.00 | Loss: 0.2098 | Q-value: 1.5253 Epsilon: 0.5264
# Episode 1290 | Score: 6.00 | Loss: 0.2338 | Q-value: 3.4475 Epsilon: 0.5238
# Episode 1300 | Score: 1.00 | Loss: 0.7386 | Q-value: 2.3371 Epsilon: 0.5212
# Episode 1300, Avg Score: 2.54
# Episode 1310 | Score: 4.00 | Loss: 0.2927 | Q-value: 5.9014 Epsilon: 0.5186
# Episode 1320 | Score: 2.00 | Loss: 0.1218 | Q-value: 2.9853 Epsilon: 0.5160
# Episode 1330 | Score: 0.00 | Loss: 0.1489 | Q-value: 2.0634 Epsilon: 0.5134
# Episode 1340 | Score: 2.00 | Loss: 0.2783 | Q-value: 4.2770 Epsilon: 0.5108
# Episode 1350 | Score: 1.00 | Loss: 0.2543 | Q-value: 3.8151 Epsilon: 0.5083
# Episode 1350, Avg Score: 2.52
# Episode 1360 | Score: 1.00 | Loss: 0.3189 | Q-value: 3.9452 Epsilon: 0.5058
# Episode 1370 | Score: 1.00 | Loss: 0.0850 | Q-value: 2.2903 Epsilon: 0.5032
# Episode 1380 | Score: 5.00 | Loss: 0.1248 | Q-value: 3.5266 Epsilon: 0.5007
# Episode 1390 | Score: 2.00 | Loss: 0.2519 | Q-value: 4.4537 Epsilon: 0.4982
# Episode 1400 | Score: 1.00 | Loss: 0.3848 | Q-value: 3.3871 Epsilon: 0.4957
# Episode 1400, Avg Score: 2.54
# Episode 1410 | Score: 1.00 | Loss: 0.5526 | Q-value: 4.7771 Epsilon: 0.4932
# Episode 1420 | Score: 0.00 | Loss: 0.5425 | Q-value: 3.6337 Epsilon: 0.4908
# Episode 1430 | Score: 2.00 | Loss: 0.2601 | Q-value: 3.1535 Epsilon: 0.4883
# Episode 1440 | Score: 0.00 | Loss: 1.6141 | Q-value: 4.3994 Epsilon: 0.4859
# Episode 1450 | Score: 3.00 | Loss: 0.3428 | Q-value: 3.5922 Epsilon: 0.4834
# Episode 1450, Avg Score: 2.52
# Episode 1460 | Score: 3.00 | Loss: 0.2168 | Q-value: 3.9533 Epsilon: 0.4810
# Episode 1470 | Score: 2.00 | Loss: 0.3507 | Q-value: 3.5321 Epsilon: 0.4786
# Episode 1480 | Score: 5.00 | Loss: 0.2650 | Q-value: 4.2650 Epsilon: 0.4762
# Episode 1490 | Score: 4.00 | Loss: 0.2679 | Q-value: 4.1434 Epsilon: 0.4738
# Episode 1500 | Score: 0.00 | Loss: 0.4649 | Q-value: 3.7361 Epsilon: 0.4715
# Episode 1500, Avg Score: 2.24
# Episode 1510 | Score: 0.00 | Loss: 0.9198 | Q-value: 3.4067 Epsilon: 0.4691
# Episode 1520 | Score: 0.00 | Loss: 0.3277 | Q-value: 2.8363 Epsilon: 0.4668
# Episode 1530 | Score: 3.00 | Loss: 0.1573 | Q-value: 2.2571 Epsilon: 0.4644
# Episode 1540 | Score: 2.00 | Loss: 0.2120 | Q-value: 2.1324 Epsilon: 0.4621
# Episode 1550 | Score: 0.00 | Loss: 0.2741 | Q-value: 2.8320 Epsilon: 0.4598
# Episode 1550, Avg Score: 1.66
# Episode 1560 | Score: 3.00 | Loss: 0.3168 | Q-value: 4.5176 Epsilon: 0.4575
# Episode 1570 | Score: 2.00 | Loss: 0.2857 | Q-value: 3.2929 Epsilon: 0.4552
# Episode 1580 | Score: 5.00 | Loss: 0.1747 | Q-value: 2.9536 Epsilon: 0.4529
# Episode 1590 | Score: 3.00 | Loss: 0.1642 | Q-value: 2.2883 Epsilon: 0.4507
# Episode 1600 | Score: 2.00 | Loss: 0.2088 | Q-value: 2.5996 Epsilon: 0.4484
# Episode 1600, Avg Score: 1.78
# Episode 1610 | Score: 1.00 | Loss: 0.2940 | Q-value: 4.1960 Epsilon: 0.4462
# Episode 1620 | Score: 4.00 | Loss: 0.1386 | Q-value: 4.1007 Epsilon: 0.4440
# Episode 1630 | Score: 3.00 | Loss: 0.1047 | Q-value: 4.1055 Epsilon: 0.4417
# Episode 1640 | Score: 2.00 | Loss: 0.3540 | Q-value: 2.7552 Epsilon: 0.4395
# Episode 1650 | Score: 5.00 | Loss: 0.1278 | Q-value: 3.6663 Epsilon: 0.4373
# Episode 1650, Avg Score: 2.42
# Episode 1660 | Score: 0.00 | Loss: 1.0686 | Q-value: 2.7518 Epsilon: 0.4351
# Episode 1670 | Score: 2.00 | Loss: 0.1530 | Q-value: 3.2148 Epsilon: 0.4330
# Episode 1680 | Score: 4.00 | Loss: 0.1420 | Q-value: 3.5702 Epsilon: 0.4308
# Episode 1690 | Score: 6.00 | Loss: 0.2019 | Q-value: 3.7804 Epsilon: 0.4286
# Episode 1700 | Score: 2.00 | Loss: 0.1923 | Q-value: 3.3662 Epsilon: 0.4265
# Episode 1700, Avg Score: 2.08
# Episode 1710 | Score: 2.00 | Loss: 0.3407 | Q-value: 4.0938 Epsilon: 0.4244
# Episode 1720 | Score: 3.00 | Loss: 0.1629 | Q-value: 4.2597 Epsilon: 0.4223
# Episode 1730 | Score: 0.00 | Loss: 1.1831 | Q-value: 4.8212 Epsilon: 0.4201
# Episode 1740 | Score: 2.00 | Loss: 0.3094 | Q-value: 4.8247 Epsilon: 0.4180
# Episode 1750 | Score: 0.00 | Loss: 0.3381 | Q-value: 4.6034 Epsilon: 0.4159
# Episode 1750, Avg Score: 2.16
# Episode 1760 | Score: 0.00 | Loss: 0.2713 | Q-value: 2.0283 Epsilon: 0.4139
# Episode 1770 | Score: 5.00 | Loss: 0.1779 | Q-value: 3.3697 Epsilon: 0.4118
# Episode 1780 | Score: 3.00 | Loss: 0.2542 | Q-value: 4.7568 Epsilon: 0.4097
# Episode 1790 | Score: 0.00 | Loss: 0.2192 | Q-value: 4.2099 Epsilon: 0.4077
# Episode 1800 | Score: 0.00 | Loss: 0.2536 | Q-value: 2.1513 Epsilon: 0.4057
# Episode 1800, Avg Score: 1.90
# Episode 1810 | Score: 0.00 | Loss: 0.2866 | Q-value: 1.9676 Epsilon: 0.4036
# Episode 1820 | Score: 2.00 | Loss: 0.1313 | Q-value: 2.9838 Epsilon: 0.4016
# Episode 1830 | Score: 4.00 | Loss: 0.0799 | Q-value: 2.9013 Epsilon: 0.3996
# Episode 1840 | Score: 2.00 | Loss: 0.3997 | Q-value: 3.2181 Epsilon: 0.3976
# Episode 1850 | Score: 0.00 | Loss: 0.1048 | Q-value: 1.8219 Epsilon: 0.3956
# Episode 1850, Avg Score: 1.56
# Episode 1860 | Score: 1.00 | Loss: 0.6058 | Q-value: 4.0219 Epsilon: 0.3936
# Episode 1870 | Score: 4.00 | Loss: 0.1541 | Q-value: 3.2334 Epsilon: 0.3917
# Episode 1880 | Score: 2.00 | Loss: 0.1659 | Q-value: 3.2289 Epsilon: 0.3897
# Episode 1890 | Score: 3.00 | Loss: 0.1653 | Q-value: 4.4555 Epsilon: 0.3878
# Episode 1900 | Score: 1.00 | Loss: 0.1806 | Q-value: 1.6499 Epsilon: 0.3858
# Episode 1900, Avg Score: 1.28
# Episode 1910 | Score: 1.00 | Loss: 0.1592 | Q-value: 3.3403 Epsilon: 0.3839
# Episode 1920 | Score: 0.00 | Loss: 0.4398 | Q-value: 1.9957 Epsilon: 0.3820
# Episode 1930 | Score: 0.00 | Loss: 0.2246 | Q-value: 4.1539 Epsilon: 0.3801
# Episode 1940 | Score: 4.00 | Loss: 0.1400 | Q-value: 2.6428 Epsilon: 0.3782
# Episode 1950 | Score: 3.00 | Loss: 0.1895 | Q-value: 4.0526 Epsilon: 0.3763
# Episode 1950, Avg Score: 1.82
# Episode 1960 | Score: 0.00 | Loss: 0.5041 | Q-value: 3.2714 Epsilon: 0.3744
# Episode 1970 | Score: 0.00 | Loss: 0.1719 | Q-value: 2.7629 Epsilon: 0.3725
# Episode 1980 | Score: 2.00 | Loss: 0.2553 | Q-value: 4.6975 Epsilon: 0.3707
# Episode 1990 | Score: 1.00 | Loss: 0.5306 | Q-value: 3.9933 Epsilon: 0.3688
# Episode 2000 | Score: 0.00 | Loss: 0.6333 | Q-value: 2.6080 Epsilon: 0.3670
# Episode 2000, Avg Score: 1.60
# Episode 2010 | Score: 3.00 | Loss: 0.2543 | Q-value: 3.7777 Epsilon: 0.3651
# Episode 2020 | Score: 2.00 | Loss: 0.0952 | Q-value: 3.3513 Epsilon: 0.3633
# Episode 2030 | Score: 2.00 | Loss: 0.1557 | Q-value: 3.6708 Epsilon: 0.3615
# Episode 2040 | Score: 0.00 | Loss: 0.3164 | Q-value: 2.6005 Epsilon: 0.3597
# Episode 2050 | Score: 0.00 | Loss: 0.1305 | Q-value: 2.6421 Epsilon: 0.3579
# Episode 2050, Avg Score: 1.12
# Episode 2060 | Score: 3.00 | Loss: 0.0877 | Q-value: 2.3642 Epsilon: 0.3561
# Episode 2070 | Score: 1.00 | Loss: 0.2330 | Q-value: 2.1830 Epsilon: 0.3543
# Episode 2080 | Score: 1.00 | Loss: 0.0624 | Q-value: 2.8441 Epsilon: 0.3525
# Episode 2090 | Score: 1.00 | Loss: 0.1610 | Q-value: 2.6265 Epsilon: 0.3508
# Episode 2100 | Score: 0.00 | Loss: 0.1267 | Q-value: 2.5530 Epsilon: 0.3490
# Episode 2100, Avg Score: 0.92
# Episode 2110 | Score: 1.00 | Loss: 0.5170 | Q-value: 3.4493 Epsilon: 0.3473
# Episode 2120 | Score: 0.00 | Loss: 0.1582 | Q-value: 2.1650 Epsilon: 0.3455
# Episode 2130 | Score: 2.00 | Loss: 0.0670 | Q-value: 3.3127 Epsilon: 0.3438
# Episode 2140 | Score: 0.00 | Loss: 0.0639 | Q-value: 1.9904 Epsilon: 0.3421
# Episode 2150 | Score: 1.00 | Loss: 0.4056 | Q-value: 3.4574 Epsilon: 0.3404
# Episode 2150, Avg Score: 1.06
# Episode 2160 | Score: 0.00 | Loss: 1.0542 | Q-value: 3.4655 Epsilon: 0.3387
# Episode 2170 | Score: 2.00 | Loss: 0.4066 | Q-value: 3.1361 Epsilon: 0.3370
# Episode 2180 | Score: 1.00 | Loss: 0.0991 | Q-value: 3.8927 Epsilon: 0.3353
# Episode 2190 | Score: 1.00 | Loss: 0.8628 | Q-value: 4.0256 Epsilon: 0.3336
# Episode 2200 | Score: 0.00 | Loss: 1.1180 | Q-value: 2.9907 Epsilon: 0.3320
# Episode 2200, Avg Score: 0.86
# Episode 2210 | Score: 1.00 | Loss: 0.1803 | Q-value: 3.7867 Epsilon: 0.3303
# Episode 2220 | Score: 1.00 | Loss: 0.1237 | Q-value: 3.4297 Epsilon: 0.3286
# Episode 2230 | Score: 2.00 | Loss: 0.0766 | Q-value: 2.7910 Epsilon: 0.3270
# Episode 2240 | Score: 3.00 | Loss: 0.1230 | Q-value: 3.8510 Epsilon: 0.3254
# Episode 2250 | Score: 0.00 | Loss: 0.2039 | Q-value: 2.8515 Epsilon: 0.3237
# Episode 2250, Avg Score: 0.92
# Episode 2260 | Score: 0.00 | Loss: 0.0707 | Q-value: 3.0293 Epsilon: 0.3221
# Episode 2270 | Score: 1.00 | Loss: 0.0709 | Q-value: 3.2396 Epsilon: 0.3205
# Episode 2280 | Score: 4.00 | Loss: 0.2079 | Q-value: 3.1557 Epsilon: 0.3189
# Episode 2290 | Score: 2.00 | Loss: 0.0636 | Q-value: 3.1569 Epsilon: 0.3173
# Episode 2300 | Score: 2.00 | Loss: 0.0477 | Q-value: 2.6005 Epsilon: 0.3157
# Episode 2300, Avg Score: 0.92
# Episode 2310 | Score: 0.00 | Loss: 0.2560 | Q-value: 2.7719 Epsilon: 0.3141
# Episode 2320 | Score: 0.00 | Loss: 0.1696 | Q-value: 2.2755 Epsilon: 0.3126
# Episode 2330 | Score: 0.00 | Loss: 0.0467 | Q-value: 2.4332 Epsilon: 0.3110
# Episode 2340 | Score: 0.00 | Loss: 0.3987 | Q-value: 4.4151 Epsilon: 0.3095
# Episode 2350 | Score: 2.00 | Loss: 0.1711 | Q-value: 3.4237 Epsilon: 0.3079
# Episode 2350, Avg Score: 1.08
# Episode 2360 | Score: 0.00 | Loss: 0.1618 | Q-value: 2.9713 Epsilon: 0.3064
# Episode 2370 | Score: 0.00 | Loss: 0.1190 | Q-value: 2.4599 Epsilon: 0.3048
# Episode 2380 | Score: 2.00 | Loss: 0.1819 | Q-value: 3.3080 Epsilon: 0.3033
# Episode 2390 | Score: 0.00 | Loss: 0.1130 | Q-value: 3.1877 Epsilon: 0.3018
# Episode 2400 | Score: 2.00 | Loss: 0.0959 | Q-value: 3.6640 Epsilon: 0.3003
# Episode 2400, Avg Score: 0.76
# Episode 2410 | Score: 1.00 | Loss: 0.0814 | Q-value: 2.8120 Epsilon: 0.2988
# Episode 2420 | Score: 0.00 | Loss: 0.0234 | Q-value: 3.2825 Epsilon: 0.2973
# Episode 2430 | Score: 2.00 | Loss: 0.3513 | Q-value: 3.7563 Epsilon: 0.2958
# Episode 2440 | Score: 2.00 | Loss: 0.0473 | Q-value: 3.1474 Epsilon: 0.2943
# Episode 2450 | Score: 3.00 | Loss: 0.1314 | Q-value: 2.6349 Epsilon: 0.2929
# Episode 2450, Avg Score: 0.92
# Episode 2460 | Score: 1.00 | Loss: 0.0369 | Q-value: 2.7224 Epsilon: 0.2914
# Episode 2470 | Score: 2.00 | Loss: 0.0565 | Q-value: 2.5071 Epsilon: 0.2899
# Episode 2480 | Score: 1.00 | Loss: 0.0524 | Q-value: 2.6062 Epsilon: 0.2885
# Episode 2490 | Score: 1.00 | Loss: 0.0682 | Q-value: 2.7447 Epsilon: 0.2870
# Episode 2500 | Score: 0.00 | Loss: 0.0732 | Q-value: 2.1190 Epsilon: 0.2856
# Episode 2500, Avg Score: 0.82
# Episode 2510 | Score: 1.00 | Loss: 0.0547 | Q-value: 2.0985 Epsilon: 0.2842
# Episode 2520 | Score: 0.00 | Loss: 0.0390 | Q-value: 1.9624 Epsilon: 0.2828
# Episode 2530 | Score: 1.00 | Loss: 0.0483 | Q-value: 2.0489 Epsilon: 0.2813
# Episode 2540 | Score: 1.00 | Loss: 0.0520 | Q-value: 2.1425 Epsilon: 0.2799
# Episode 2550 | Score: 0.00 | Loss: 0.0779 | Q-value: 1.8176 Epsilon: 0.2785
# Episode 2550, Avg Score: 0.80
# Episode 2560 | Score: 0.00 | Loss: 0.1892 | Q-value: 2.5341 Epsilon: 0.2771
# Episode 2570 | Score: 6.00 | Loss: 0.1044 | Q-value: 2.7191 Epsilon: 0.2758
# Episode 2580 | Score: 0.00 | Loss: 0.3235 | Q-value: 2.3772 Epsilon: 0.2744
# Episode 2590 | Score: 0.00 | Loss: 0.0803 | Q-value: 2.1943 Epsilon: 0.2730
# Episode 2600 | Score: 5.00 | Loss: 0.0824 | Q-value: 2.3395 Epsilon: 0.2716
# Episode 2600, Avg Score: 1.04
# Episode 2610 | Score: 0.00 | Loss: 0.1348 | Q-value: 3.2943 Epsilon: 0.2703
# Episode 2620 | Score: 5.00 | Loss: 0.0546 | Q-value: 2.5690 Epsilon: 0.2689
# Episode 2630 | Score: 1.00 | Loss: 0.0795 | Q-value: 1.9527 Epsilon: 0.2676
# Episode 2640 | Score: 2.00 | Loss: 0.1208 | Q-value: 1.9809 Epsilon: 0.2663
# Episode 2650 | Score: 2.00 | Loss: 0.0874 | Q-value: 2.2843 Epsilon: 0.2649
# Episode 2650, Avg Score: 1.18
# Episode 2660 | Score: 3.00 | Loss: 0.0690 | Q-value: 1.9725 Epsilon: 0.2636
# Episode 2670 | Score: 1.00 | Loss: 0.0416 | Q-value: 1.6566 Epsilon: 0.2623
# Episode 2680 | Score: 1.00 | Loss: 0.0321 | Q-value: 1.1873 Epsilon: 0.2610
# Episode 2690 | Score: 0.00 | Loss: 0.4860 | Q-value: 1.1250 Epsilon: 0.2597
# Episode 2700 | Score: 2.00 | Loss: 0.2119 | Q-value: 2.0725 Epsilon: 0.2584
# Episode 2700, Avg Score: 0.88
# Episode 2710 | Score: 0.00 | Loss: 0.2592 | Q-value: 1.9428 Epsilon: 0.2571
# Episode 2720 | Score: 0.00 | Loss: 0.1025 | Q-value: 1.9548 Epsilon: 0.2558
# Episode 2730 | Score: 0.00 | Loss: 0.0449 | Q-value: 1.3436 Epsilon: 0.2545
# Episode 2740 | Score: 0.00 | Loss: 0.6325 | Q-value: 2.2503 Epsilon: 0.2532
# Episode 2750 | Score: 1.00 | Loss: 0.0616 | Q-value: 2.2554 Epsilon: 0.2520
# Episode 2750, Avg Score: 0.72
# Episode 2760 | Score: 0.00 | Loss: 0.1309 | Q-value: 2.0226 Epsilon: 0.2507
# Episode 2770 | Score: 0.00 | Loss: 0.1630 | Q-value: 1.8886 Epsilon: 0.2495
# Episode 2780 | Score: 3.00 | Loss: 0.0606 | Q-value: 1.7546 Epsilon: 0.2482
# Episode 2790 | Score: 1.00 | Loss: 0.0178 | Q-value: 1.3461 Epsilon: 0.2470
# Episode 2800 | Score: 2.00 | Loss: 0.0753 | Q-value: 1.5102 Epsilon: 0.2457
# Episode 2800, Avg Score: 0.74
# Episode 2810 | Score: 2.00 | Loss: 0.0535 | Q-value: 1.7957 Epsilon: 0.2445
# Episode 2820 | Score: 3.00 | Loss: 0.0335 | Q-value: 1.4859 Epsilon: 0.2433
# Episode 2830 | Score: 1.00 | Loss: 0.0494 | Q-value: 1.8840 Epsilon: 0.2421
# Episode 2840 | Score: 0.00 | Loss: 0.0457 | Q-value: 1.3420 Epsilon: 0.2409
# Episode 2850 | Score: 0.00 | Loss: 0.0149 | Q-value: 1.4041 Epsilon: 0.2397
# Episode 2850, Avg Score: 0.98
# Episode 2860 | Score: 0.00 | Loss: 0.0447 | Q-value: 1.8453 Epsilon: 0.2385
# Episode 2870 | Score: 0.00 | Loss: 0.0300 | Q-value: 1.2551 Epsilon: 0.2373
# Episode 2880 | Score: 0.00 | Loss: 0.0305 | Q-value: 1.2500 Epsilon: 0.2361
# Episode 2890 | Score: 0.00 | Loss: 0.0243 | Q-value: 1.0987 Epsilon: 0.2349
# Episode 2900 | Score: 1.00 | Loss: 0.1669 | Q-value: 1.6070 Epsilon: 0.2337
# Episode 2900, Avg Score: 1.18
# Episode 2910 | Score: 2.00 | Loss: 0.0605 | Q-value: 2.2273 Epsilon: 0.2326
# Episode 2920 | Score: 2.00 | Loss: 0.1079 | Q-value: 2.4851 Epsilon: 0.2314
# Episode 2930 | Score: 0.00 | Loss: 0.2080 | Q-value: 1.8175 Epsilon: 0.2302
# Episode 2940 | Score: 1.00 | Loss: 0.0657 | Q-value: 1.6612 Epsilon: 0.2291
# Episode 2950 | Score: 3.00 | Loss: 0.0459 | Q-value: 1.9828 Epsilon: 0.2279
# Episode 2950, Avg Score: 1.14
# Episode 2960 | Score: 0.00 | Loss: 0.0399 | Q-value: 1.1399 Epsilon: 0.2268
# Episode 2970 | Score: 1.00 | Loss: 0.0312 | Q-value: 1.8467 Epsilon: 0.2257
# Episode 2980 | Score: 0.00 | Loss: 0.0162 | Q-value: 0.9810 Epsilon: 0.2245
# Episode 2990 | Score: 1.00 | Loss: 0.0851 | Q-value: 1.8334 Epsilon: 0.2234
# Episode 3000 | Score: 0.00 | Loss: 0.0330 | Q-value: 1.1998 Epsilon: 0.2223
# Episode 3000, Avg Score: 0.76
# Episode 3010 | Score: 1.00 | Loss: 0.0703 | Q-value: 1.0295 Epsilon: 0.2212
# Episode 3020 | Score: 1.00 | Loss: 0.0322 | Q-value: 1.3101 Epsilon: 0.2201
# Episode 3030 | Score: 0.00 | Loss: 0.0214 | Q-value: 1.0614 Epsilon: 0.2190
# Episode 3040 | Score: 0.00 | Loss: 0.0997 | Q-value: 0.8807 Epsilon: 0.2179
# Episode 3050 | Score: 0.00 | Loss: 0.3836 | Q-value: 0.8499 Epsilon: 0.2168
# Episode 3050, Avg Score: 0.58
# Episode 3060 | Score: 2.00 | Loss: 0.0613 | Q-value: 1.5464 Epsilon: 0.2157
# Episode 3070 | Score: 2.00 | Loss: 0.0610 | Q-value: 1.2488 Epsilon: 0.2146
# Episode 3080 | Score: 1.00 | Loss: 0.0161 | Q-value: 1.1444 Epsilon: 0.2136
# Episode 3090 | Score: 1.00 | Loss: 0.0404 | Q-value: 1.1340 Epsilon: 0.2125
# Episode 3100 | Score: 0.00 | Loss: 0.3605 | Q-value: 0.6506 Epsilon: 0.2114
# Episode 3100, Avg Score: 0.66
# Episode 3110 | Score: 1.00 | Loss: 0.0633 | Q-value: 1.4878 Epsilon: 0.2104
# Episode 3120 | Score: 2.00 | Loss: 0.0699 | Q-value: 1.9181 Epsilon: 0.2093
# Episode 3130 | Score: 2.00 | Loss: 0.0488 | Q-value: 1.8696 Epsilon: 0.2083
# Episode 3140 | Score: 2.00 | Loss: 0.0350 | Q-value: 1.5662 Epsilon: 0.2072
# Episode 3150 | Score: 2.00 | Loss: 0.0396 | Q-value: 1.6163 Epsilon: 0.2062
# Episode 3150, Avg Score: 1.28
# Episode 3160 | Score: 2.00 | Loss: 0.0211 | Q-value: 1.4234 Epsilon: 0.2052
# Episode 3170 | Score: 1.00 | Loss: 0.0395 | Q-value: 1.3635 Epsilon: 0.2041
# Episode 3180 | Score: 0.00 | Loss: 0.0135 | Q-value: 0.9421 Epsilon: 0.2031
# Episode 3190 | Score: 0.00 | Loss: 0.1364 | Q-value: 1.2434 Epsilon: 0.2021
# Episode 3200 | Score: 3.00 | Loss: 0.0324 | Q-value: 1.3711 Epsilon: 0.2011
# Episode 3200, Avg Score: 0.56
# Episode 3210 | Score: 0.00 | Loss: 0.0244 | Q-value: 1.1174 Epsilon: 0.2001
# Episode 3220 | Score: 0.00 | Loss: 0.0125 | Q-value: 0.8715 Epsilon: 0.1991
# Episode 3230 | Score: 0.00 | Loss: 0.0624 | Q-value: 1.0240 Epsilon: 0.1981
# Episode 3240 | Score: 2.00 | Loss: 0.0808 | Q-value: 1.6350 Epsilon: 0.1971
# Episode 3250 | Score: 0.00 | Loss: 0.0454 | Q-value: 1.3592 Epsilon: 0.1961
# Episode 3250, Avg Score: 1.02
# Episode 3260 | Score: 1.00 | Loss: 0.0642 | Q-value: 1.8829 Epsilon: 0.1951
# Episode 3270 | Score: 1.00 | Loss: 0.0238 | Q-value: 1.2387 Epsilon: 0.1942
# Episode 3280 | Score: 2.00 | Loss: 0.0579 | Q-value: 1.5132 Epsilon: 0.1932
# Episode 3290 | Score: 2.00 | Loss: 0.0648 | Q-value: 1.4689 Epsilon: 0.1922
# Episode 3300 | Score: 1.00 | Loss: 0.0696 | Q-value: 1.3879 Epsilon: 0.1913
# Episode 3300, Avg Score: 1.04
# Episode 3310 | Score: 0.00 | Loss: 0.0566 | Q-value: 1.3211 Epsilon: 0.1903
# Episode 3320 | Score: 1.00 | Loss: 0.0225 | Q-value: 1.2464 Epsilon: 0.1893
# Episode 3330 | Score: 1.00 | Loss: 0.0690 | Q-value: 1.9143 Epsilon: 0.1884
# Episode 3340 | Score: 2.00 | Loss: 0.0475 | Q-value: 1.4756 Epsilon: 0.1875
# Episode 3350 | Score: 2.00 | Loss: 0.0188 | Q-value: 1.3584 Epsilon: 0.1865
# Episode 3350, Avg Score: 0.82
# Episode 3360 | Score: 1.00 | Loss: 0.0210 | Q-value: 1.2681 Epsilon: 0.1856
# Episode 3370 | Score: 0.00 | Loss: 0.0544 | Q-value: 1.2705 Epsilon: 0.1847
# Episode 3380 | Score: 1.00 | Loss: 0.0834 | Q-value: 1.3103 Epsilon: 0.1837
# Episode 3390 | Score: 2.00 | Loss: 0.0645 | Q-value: 1.1274 Epsilon: 0.1828
# Episode 3400 | Score: 0.00 | Loss: 0.0169 | Q-value: 1.0762 Epsilon: 0.1819
# Episode 3400, Avg Score: 0.86
# Episode 3410 | Score: 0.00 | Loss: 0.0124 | Q-value: 0.8312 Epsilon: 0.1810
# Episode 3420 | Score: 0.00 | Loss: 0.2291 | Q-value: 0.8443 Epsilon: 0.1801
# Episode 3430 | Score: 0.00 | Loss: 0.0654 | Q-value: 1.0814 Epsilon: 0.1792
# Episode 3440 | Score: 1.00 | Loss: 0.0329 | Q-value: 1.3910 Epsilon: 0.1783
# Episode 3450 | Score: 0.00 | Loss: 0.0116 | Q-value: 0.8608 Epsilon: 0.1774
# Episode 3450, Avg Score: 0.74
# Episode 3460 | Score: 0.00 | Loss: 0.0147 | Q-value: 1.1106 Epsilon: 0.1765
# Episode 3470 | Score: 2.00 | Loss: 0.0298 | Q-value: 1.4582 Epsilon: 0.1756
# Episode 3480 | Score: 1.00 | Loss: 0.2956 | Q-value: 1.8640 Epsilon: 0.1748
# Episode 3490 | Score: 4.00 | Loss: 0.0593 | Q-value: 1.9702 Epsilon: 0.1739
# Episode 3500 | Score: 1.00 | Loss: 0.0173 | Q-value: 1.0849 Epsilon: 0.1730
# Episode 3500, Avg Score: 1.18
# Episode 3510 | Score: 3.00 | Loss: 0.0244 | Q-value: 0.7650 Epsilon: 0.1721
# Episode 3520 | Score: 0.00 | Loss: 0.0361 | Q-value: 1.1561 Epsilon: 0.1713
# Episode 3530 | Score: 0.00 | Loss: 0.1018 | Q-value: 1.3171 Epsilon: 0.1704
# Episode 3540 | Score: 1.00 | Loss: 0.0276 | Q-value: 1.2627 Epsilon: 0.1696
# Episode 3550 | Score: 0.00 | Loss: 0.0263 | Q-value: 0.8731 Epsilon: 0.1687
# Episode 3550, Avg Score: 0.92
# Episode 3560 | Score: 0.00 | Loss: 0.1403 | Q-value: 1.0446 Epsilon: 0.1679
# Episode 3570 | Score: 2.00 | Loss: 0.0417 | Q-value: 1.1245 Epsilon: 0.1670
# Episode 3580 | Score: 1.00 | Loss: 0.0170 | Q-value: 0.9853 Epsilon: 0.1662
# Episode 3590 | Score: 0.00 | Loss: 0.0072 | Q-value: 0.6081 Epsilon: 0.1654
# Episode 3600 | Score: 0.00 | Loss: 0.0145 | Q-value: 0.6356 Epsilon: 0.1646
# Episode 3600, Avg Score: 0.70
# Episode 3610 | Score: 2.00 | Loss: 0.0226 | Q-value: 0.9206 Epsilon: 0.1637
# Episode 3620 | Score: 2.00 | Loss: 0.0719 | Q-value: 1.1039 Epsilon: 0.1629
# Episode 3630 | Score: 0.00 | Loss: 0.0226 | Q-value: 0.8552 Epsilon: 0.1621
# Episode 3640 | Score: 0.00 | Loss: 0.0813 | Q-value: 0.6546 Epsilon: 0.1613
# Episode 3650 | Score: 0.00 | Loss: 0.0347 | Q-value: 1.3063 Epsilon: 0.1605
# Episode 3650, Avg Score: 1.06
# Episode 3660 | Score: 1.00 | Loss: 0.1051 | Q-value: 1.0933 Epsilon: 0.1597
# Episode 3670 | Score: 1.00 | Loss: 0.0475 | Q-value: 1.0740 Epsilon: 0.1589
# Episode 3680 | Score: 3.00 | Loss: 0.0218 | Q-value: 0.8867 Epsilon: 0.1581
# Episode 3690 | Score: 0.00 | Loss: 0.0556 | Q-value: 1.1913 Epsilon: 0.1573
# Episode 3700 | Score: 0.00 | Loss: 0.0252 | Q-value: 0.9895 Epsilon: 0.1565
# Episode 3700, Avg Score: 0.98
# Episode 3710 | Score: 0.00 | Loss: 0.0178 | Q-value: 0.7624 Epsilon: 0.1557
# Episode 3720 | Score: 0.00 | Loss: 0.0366 | Q-value: 1.0121 Epsilon: 0.1549
# Episode 3730 | Score: 0.00 | Loss: 0.0107 | Q-value: 0.7552 Epsilon: 0.1542
# Episode 3740 | Score: 3.00 | Loss: 0.0192 | Q-value: 0.9712 Epsilon: 0.1534
# Episode 3750 | Score: 1.00 | Loss: 0.0215 | Q-value: 0.8582 Epsilon: 0.1526
# Episode 3750, Avg Score: 0.64
# Episode 3760 | Score: 0.00 | Loss: 0.0456 | Q-value: 1.0734 Epsilon: 0.1519
# Episode 3770 | Score: 0.00 | Loss: 0.0205 | Q-value: 0.4555 Epsilon: 0.1511
# Episode 3780 | Score: 2.00 | Loss: 0.0079 | Q-value: 0.7672 Epsilon: 0.1504
# Episode 3790 | Score: 1.00 | Loss: 0.0211 | Q-value: 0.7280 Epsilon: 0.1496
# Episode 3800 | Score: 0.00 | Loss: 0.1579 | Q-value: 0.4839 Epsilon: 0.1489
# Episode 3800, Avg Score: 0.66
# Episode 3810 | Score: 0.00 | Loss: 0.0066 | Q-value: 0.6424 Epsilon: 0.1481
# Episode 3820 | Score: 3.00 | Loss: 0.0235 | Q-value: 0.9205 Epsilon: 0.1474
# Episode 3830 | Score: 2.00 | Loss: 0.0398 | Q-value: 1.0688 Epsilon: 0.1466
# Episode 3840 | Score: 0.00 | Loss: 0.0288 | Q-value: 0.8817 Epsilon: 0.1459
# Episode 3850 | Score: 0.00 | Loss: 0.0918 | Q-value: 0.6668 Epsilon: 0.1452
# Episode 3850, Avg Score: 0.58
# Episode 3860 | Score: 0.00 | Loss: 0.0232 | Q-value: 0.5185 Epsilon: 0.1444
# Episode 3870 | Score: 1.00 | Loss: 0.0137 | Q-value: 0.9624 Epsilon: 0.1437
# Episode 3880 | Score: 0.00 | Loss: 0.0090 | Q-value: 0.6135 Epsilon: 0.1430
# Episode 3890 | Score: 1.00 | Loss: 0.0286 | Q-value: 0.9514 Epsilon: 0.1423
# Episode 3900 | Score: 0.00 | Loss: 0.0168 | Q-value: 0.7594 Epsilon: 0.1416
# Episode 3900, Avg Score: 0.98
# Episode 3910 | Score: 2.00 | Loss: 0.0244 | Q-value: 0.9978 Epsilon: 0.1409
# Episode 3920 | Score: 0.00 | Loss: 0.0521 | Q-value: 0.6862 Epsilon: 0.1402
# Episode 3930 | Score: 6.00 | Loss: 0.0380 | Q-value: 1.1862 Epsilon: 0.1395
# Episode 3940 | Score: 1.00 | Loss: 0.0328 | Q-value: 1.0903 Epsilon: 0.1388
# Episode 3950 | Score: 2.00 | Loss: 0.0247 | Q-value: 0.7274 Epsilon: 0.1381
# Episode 3950, Avg Score: 0.66
# Episode 3960 | Score: 0.00 | Loss: 0.0253 | Q-value: 0.4617 Epsilon: 0.1374
# Episode 3970 | Score: 2.00 | Loss: 0.0229 | Q-value: 1.0020 Epsilon: 0.1367
# Episode 3980 | Score: 2.00 | Loss: 0.0152 | Q-value: 0.7667 Epsilon: 0.1360
# Episode 3990 | Score: 2.00 | Loss: 0.0272 | Q-value: 0.8283 Epsilon: 0.1353
# Episode 4000 | Score: 0.00 | Loss: 0.0061 | Q-value: 0.7533 Epsilon: 0.1347
# Episode 4000, Avg Score: 0.66
# Episode 4010 | Score: 1.00 | Loss: 0.0157 | Q-value: 0.6041 Epsilon: 0.1340
# Episode 4020 | Score: 3.00 | Loss: 0.0153 | Q-value: 1.0330 Epsilon: 0.1333
# Episode 4030 | Score: 1.00 | Loss: 0.0091 | Q-value: 0.7651 Epsilon: 0.1326
# Episode 4040 | Score: 2.00 | Loss: 0.0178 | Q-value: 0.9465 Epsilon: 0.1320
# Episode 4050 | Score: 0.00 | Loss: 0.0223 | Q-value: 0.8942 Epsilon: 0.1313
# Episode 4050, Avg Score: 0.84
# Episode 4060 | Score: 1.00 | Loss: 0.0333 | Q-value: 1.0323 Epsilon: 0.1307
# Episode 4070 | Score: 3.00 | Loss: 0.0199 | Q-value: 1.0662 Epsilon: 0.1300
# Episode 4080 | Score: 0.00 | Loss: 0.0294 | Q-value: 0.8294 Epsilon: 0.1294
# Episode 4090 | Score: 1.00 | Loss: 0.0191 | Q-value: 0.8300 Epsilon: 0.1287
# Episode 4100 | Score: 0.00 | Loss: 0.0145 | Q-value: 0.5024 Epsilon: 0.1281
# Episode 4100, Avg Score: 0.86
# Episode 4110 | Score: 0.00 | Loss: 0.0263 | Q-value: 0.5771 Epsilon: 0.1274
# Episode 4120 | Score: 0.00 | Loss: 0.0922 | Q-value: 0.8048 Epsilon: 0.1268
# Episode 4130 | Score: 0.00 | Loss: 0.0293 | Q-value: 0.4056 Epsilon: 0.1262
# Episode 4140 | Score: 4.00 | Loss: 0.0249 | Q-value: 0.8074 Epsilon: 0.1255
# Episode 4150 | Score: 0.00 | Loss: 0.2065 | Q-value: 0.3648 Epsilon: 0.1249
# Episode 4150, Avg Score: 0.50
# Episode 4160 | Score: 0.00 | Loss: 0.0577 | Q-value: 0.3159 Epsilon: 0.1243
# Episode 4170 | Score: 0.00 | Loss: 0.0120 | Q-value: 0.5575 Epsilon: 0.1237
# Episode 4180 | Score: 3.00 | Loss: 0.0667 | Q-value: 0.8686 Epsilon: 0.1230
# Episode 4190 | Score: 1.00 | Loss: 0.0168 | Q-value: 0.7309 Epsilon: 0.1224
# Episode 4200 | Score: 0.00 | Loss: 0.0101 | Q-value: 0.5067 Epsilon: 0.1218
# Episode 4200, Avg Score: 0.66
# Episode 4210 | Score: 1.00 | Loss: 0.0134 | Q-value: 0.5984 Epsilon: 0.1212
# Episode 4220 | Score: 0.00 | Loss: 0.0092 | Q-value: 0.6600 Epsilon: 0.1206
# Episode 4230 | Score: 0.00 | Loss: 0.1166 | Q-value: 0.8257 Epsilon: 0.1200
# Episode 4240 | Score: 2.00 | Loss: 0.0368 | Q-value: 0.9117 Epsilon: 0.1194
# Episode 4250 | Score: 0.00 | Loss: 0.0544 | Q-value: 0.4581 Epsilon: 0.1188
# Episode 4250, Avg Score: 0.86
# Episode 4260 | Score: 0.00 | Loss: 0.0055 | Q-value: 0.4078 Epsilon: 0.1182
# Episode 4270 | Score: 0.00 | Loss: 0.0331 | Q-value: 0.4391 Epsilon: 0.1176
# Episode 4280 | Score: 0.00 | Loss: 0.0128 | Q-value: 0.4952 Epsilon: 0.1170
# Episode 4290 | Score: 1.00 | Loss: 0.0457 | Q-value: 0.8877 Epsilon: 0.1164
# Episode 4300 | Score: 2.00 | Loss: 0.0168 | Q-value: 0.8430 Epsilon: 0.1159
# Episode 4300, Avg Score: 0.68
# Episode 4310 | Score: 1.00 | Loss: 0.0483 | Q-value: 0.6271 Epsilon: 0.1153
# Episode 4320 | Score: 0.00 | Loss: 0.0063 | Q-value: 0.7821 Epsilon: 0.1147
# Episode 4330 | Score: 0.00 | Loss: 0.0543 | Q-value: 0.3228 Epsilon: 0.1141
# Episode 4340 | Score: 0.00 | Loss: 0.0053 | Q-value: 0.3038 Epsilon: 0.1136
# Episode 4350 | Score: 0.00 | Loss: 0.0262 | Q-value: 0.5467 Epsilon: 0.1130
# Episode 4350, Avg Score: 0.72
# Episode 4360 | Score: 0.00 | Loss: 0.0083 | Q-value: 0.6761 Epsilon: 0.1124
# Episode 4370 | Score: 0.00 | Loss: 0.0113 | Q-value: 0.6773 Epsilon: 0.1119
# Episode 4380 | Score: 0.00 | Loss: 0.2559 | Q-value: 0.5841 Epsilon: 0.1113
# Episode 4390 | Score: 0.00 | Loss: 0.0309 | Q-value: 0.7027 Epsilon: 0.1107
# Episode 4400 | Score: 1.00 | Loss: 0.0070 | Q-value: 0.6493 Epsilon: 0.1102
# Episode 4400, Avg Score: 0.88
# Episode 4410 | Score: 2.00 | Loss: 0.0165 | Q-value: 0.4868 Epsilon: 0.1096
# Episode 4420 | Score: 0.00 | Loss: 0.0030 | Q-value: 0.2006 Epsilon: 0.1091
# Episode 4430 | Score: 1.00 | Loss: 0.0196 | Q-value: 0.6025 Epsilon: 0.1085
# Episode 4440 | Score: 0.00 | Loss: 0.0081 | Q-value: 0.5179 Epsilon: 0.1080
# Episode 4450 | Score: 0.00 | Loss: 0.0022 | Q-value: 0.4716 Epsilon: 0.1075
# Episode 4450, Avg Score: 0.56
# Episode 4460 | Score: 0.00 | Loss: 0.0112 | Q-value: 0.5905 Epsilon: 0.1069
# Episode 4470 | Score: 0.00 | Loss: 0.0356 | Q-value: 0.6615 Epsilon: 0.1064
# Episode 4480 | Score: 1.00 | Loss: 0.0141 | Q-value: 0.8159 Epsilon: 0.1059
# Episode 4490 | Score: 1.00 | Loss: 0.0085 | Q-value: 0.5489 Epsilon: 0.1053
# Episode 4500 | Score: 4.00 | Loss: 0.0353 | Q-value: 1.0362 Epsilon: 0.1048
# Episode 4500, Avg Score: 0.92
# Episode 4510 | Score: 0.00 | Loss: 0.0047 | Q-value: 0.2751 Epsilon: 0.1043
# Episode 4520 | Score: 1.00 | Loss: 0.0242 | Q-value: 0.9757 Epsilon: 0.1038
# Episode 4530 | Score: 0.00 | Loss: 0.0311 | Q-value: 0.3368 Epsilon: 0.1032
# Episode 4540 | Score: 0.00 | Loss: 0.0060 | Q-value: 0.3690 Epsilon: 0.1027
# Episode 4550 | Score: 0.00 | Loss: 0.0263 | Q-value: 0.6869 Epsilon: 0.1022
# Episode 4550, Avg Score: 0.70
# Episode 4560 | Score: 2.00 | Loss: 0.0356 | Q-value: 0.8482 Epsilon: 0.1017
# Episode 4570 | Score: 0.00 | Loss: 0.0049 | Q-value: 0.2586 Epsilon: 0.1012
# Episode 4580 | Score: 0.00 | Loss: 0.0096 | Q-value: 0.2678 Epsilon: 0.1007
# Episode 4590 | Score: 0.00 | Loss: 0.0036 | Q-value: 0.5378 Epsilon: 0.1002
# Episode 4600 | Score: 0.00 | Loss: 0.0080 | Q-value: 0.1143 Epsilon: 0.0997
# Episode 4600, Avg Score: 0.78
# Episode 4610 | Score: 1.00 | Loss: 0.0242 | Q-value: 0.3597 Epsilon: 0.0992
# Episode 4620 | Score: 0.00 | Loss: 0.0236 | Q-value: 0.2176 Epsilon: 0.0987
# Episode 4630 | Score: 1.00 | Loss: 0.0205 | Q-value: 0.6104 Epsilon: 0.0982
# Episode 4640 | Score: 0.00 | Loss: 0.0197 | Q-value: 0.3176 Epsilon: 0.0977
# Episode 4650 | Score: 1.00 | Loss: 0.0170 | Q-value: 0.6675 Epsilon: 0.0972
# Episode 4650, Avg Score: 0.50
# Episode 4660 | Score: 0.00 | Loss: 0.0039 | Q-value: 0.4848 Epsilon: 0.0967
# Episode 4670 | Score: 0.00 | Loss: 0.0313 | Q-value: 0.5667 Epsilon: 0.0962
# Episode 4680 | Score: 1.00 | Loss: 0.0196 | Q-value: 0.6532 Epsilon: 0.0958
# Episode 4690 | Score: 0.00 | Loss: 0.0130 | Q-value: 0.6889 Epsilon: 0.0953
# Episode 4700 | Score: 0.00 | Loss: 0.0069 | Q-value: 0.5230 Epsilon: 0.0948
# Episode 4700, Avg Score: 0.90
# Episode 4710 | Score: 0.00 | Loss: 0.0037 | Q-value: 0.1824 Epsilon: 0.0943
# Episode 4720 | Score: 1.00 | Loss: 0.0215 | Q-value: 0.5900 Epsilon: 0.0939
# Episode 4730 | Score: 1.00 | Loss: 0.0106 | Q-value: 0.5613 Epsilon: 0.0934
# Episode 4740 | Score: 2.00 | Loss: 0.0129 | Q-value: 0.5026 Epsilon: 0.0929
# Episode 4750 | Score: 0.00 | Loss: 0.0384 | Q-value: 0.4071 Epsilon: 0.0925
# Episode 4750, Avg Score: 0.58
# Episode 4760 | Score: 0.00 | Loss: 0.0176 | Q-value: 0.2391 Epsilon: 0.0920
# Episode 4770 | Score: 0.00 | Loss: 0.0137 | Q-value: 0.1723 Epsilon: 0.0915
# Episode 4780 | Score: 0.00 | Loss: 0.0047 | Q-value: 0.3123 Epsilon: 0.0911
# Episode 4790 | Score: 1.00 | Loss: 0.0346 | Q-value: 0.4341 Epsilon: 0.0906
# Episode 4800 | Score: 0.00 | Loss: 0.1662 | Q-value: 0.5877 Epsilon: 0.0902
# Episode 4800, Avg Score: 0.72
# Episode 4810 | Score: 0.00 | Loss: 0.0054 | Q-value: 0.4477 Epsilon: 0.0897
# Episode 4820 | Score: 0.00 | Loss: 0.0223 | Q-value: 0.1317 Epsilon: 0.0893
# Episode 4830 | Score: 2.00 | Loss: 0.0093 | Q-value: 0.4481 Epsilon: 0.0888
# Episode 4840 | Score: 2.00 | Loss: 0.0177 | Q-value: 0.6477 Epsilon: 0.0884
# Episode 4850 | Score: 0.00 | Loss: 0.0476 | Q-value: 0.2380 Epsilon: 0.0879
# Episode 4850, Avg Score: 0.62
# Episode 4860 | Score: 1.00 | Loss: 0.0101 | Q-value: 0.5297 Epsilon: 0.0875
# Episode 4870 | Score: 1.00 | Loss: 0.0530 | Q-value: 0.4869 Epsilon: 0.0871
# Episode 4880 | Score: 0.00 | Loss: 0.0054 | Q-value: 0.5720 Epsilon: 0.0866
# Episode 4890 | Score: 0.00 | Loss: 0.0680 | Q-value: 0.8942 Epsilon: 0.0862
# Episode 4900 | Score: 0.00 | Loss: 0.0221 | Q-value: 0.2259 Epsilon: 0.0858
# Episode 4900, Avg Score: 0.64
# Episode 4910 | Score: 0.00 | Loss: 0.0121 | Q-value: 0.5033 Epsilon: 0.0853
# Episode 4920 | Score: 0.00 | Loss: 0.0058 | Q-value: 0.3131 Epsilon: 0.0849
# Episode 4930 | Score: 0.00 | Loss: 0.0032 | Q-value: 0.4207 Epsilon: 0.0845
# Episode 4940 | Score: 0.00 | Loss: 0.0342 | Q-value: 0.4211 Epsilon: 0.0841
# Episode 4950 | Score: 0.00 | Loss: 0.0329 | Q-value: 0.3659 Epsilon: 0.0836
# Episode 4950, Avg Score: 0.68
# Episode 4960 | Score: 1.00 | Loss: 0.0237 | Q-value: 0.4360 Epsilon: 0.0832
# Episode 4970 | Score: 1.00 | Loss: 0.0115 | Q-value: 0.6186 Epsilon: 0.0828
# Episode 4980 | Score: 0.00 | Loss: 0.1704 | Q-value: 0.5179 Epsilon: 0.0824
# Episode 4990 | Score: 0.00 | Loss: 0.0068 | Q-value: 0.1573 Epsilon: 0.0820
# Episode 5000 | Score: 4.00 | Loss: 0.0268 | Q-value: 0.5689 Epsilon: 0.0816
# Episode 5000, Avg Score: 1.20

# %%
# Plot
plot_training_metrics(scores, losses, q_values)

# Evaluate
evaluate_efficiency(scores, q_values, total_time=end - start)
# Out:
# --- Evaluation Summary ---
# Average Score: 2.10
# Average Q-value: 2.8021
# Training Time: 2001.40 seconds
# Score / Time: 0.0010
# Q-value / Time: 0.0014

# %%
## TASK 2 ONWARDS
policy_net = SnakeDQN(state_shape, n_actions=3)
target_net = SnakeDQN(state_shape, n_actions=3)
target_net.load_state_dict(policy_net.state_dict())
target_net.eval()

#train_dqn2(game_instance, policy_net, target_net, max_train_episodes=100)
start = time.time()
scores, losses, q_values = train_dqn3(game_instance, policy_net, target_net, exploration_style="epsilon", decay_pattern="fixed", max_train_episodes=1000)
end = time.time()

# Plot
plot_training_metrics(scores, losses, q_values)

# Evaluate
evaluate_efficiency(scores, q_values, total_time=end - start)

# %% [markdown]
# # Metrics

# %%
def plot_training_metrics():
    fig, axs = plt.subplots(3, 1, figsize=(12, 12))

    axs[0].plot(episode_rewards, label='Reward per Episode')
    axs[0].plot(np.convolve(episode_rewards, np.ones(10)/10, mode='valid'), label='Smoothed (10)', linestyle='--')
    axs[0].set_title('Learning Curve')
    axs[0].set_xlabel('Episode')
    axs[0].set_ylabel('Total Reward')
    axs[0].legend()

    if epsilon_history:
        axs[1].plot(epsilon_history)
        axs[1].set_title('Epsilon Decay')
        axs[1].set_ylabel('Epsilon')
        axs[1].set_xlabel('Episode')
    elif temperature_history:
        axs[1].plot(temperature_history)
        axs[1].set_title('Temperature Decay')
        axs[1].set_ylabel('Temperature')
        axs[1].set_xlabel('Episode')

    axs[2].plot(exploration_count)
    axs[2].set_title('Exploration Rate per Episode')
    axs[2].set_ylabel('% Random Actions')
    axs[2].set_xlabel('Episode')

    plt.tight_layout()
    plt.show()

plot_training_metrics()

# %%
def plot_training_progress(scores):
    plt.figure(figsize=(10,5))
    plt.plot(scores, label='Episode Reward')

    window = 20
    if len(scores) >= window:
        moving_avg = [np.mean(scores[max(0, i-window):i+1]) for i in range(len(scores))]
        plt.plot(moving_avg, label=f'{window}-Episode Moving Average')

    plt.xlabel('Episode')
    plt.ylabel('Reward')
    plt.title('Training Progress - Reward per Episode')
    plt.legend()
    plt.grid(True)
    plt.show()


plot_training_progress(scores)
#history['info']

# %% [markdown]
# # Plot board

# %%
def plot_board(board,text=None):
    plt.figure(figsize=(2,2))
    rotated_board = np.rot90(board)
    plt.imshow(rotated_board)
    plt.axis('off')
    if text is not None:
        plt.gca().text(3, 3, text, fontsize=45,color = 'yellow')
    #plt.savefig(file_name,bbox_inches='tight')
    plt.show()
    plt.close()
